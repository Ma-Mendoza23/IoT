# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
import requests
import time
# Reemplaza con tu propia API key de lectura de ThinkSpeak y el número de canal
API_KEY = '0Y61NPPC8B92590E'
CHANNEL_ID = '2574321'

# %%
import random
import time
import json
from colorama import Fore

# Paso 1: Simular la recopilación de datos de sensores de temperatura
def simulate_temperature_data():
  # data = []
  # num_sensors = 1
  # for sensor_id in range(num_sensors):
  #   temperature = round(random.uniform(-10, 40), 2) # Temperatura simulada entre -10 y 40 grados Celsius
  #   data.append({'sensor_id': sensor_id, 'temperature': temperature, 'timestamp': time.time()})
  # return data
  url = f'https://api.thingspeak.com/channels/{CHANNEL_ID}/fields/1.json?api_key={API_KEY}&results=1'
  response = requests.get(url)
  data = response.json()
  feeds = data['feeds']
  if feeds:
    latest_entry = feeds[-1]
    temperature = float(latest_entry['field1'])
    return [{'sensor_id': CHANNEL_ID, 'temperature': temperature, 'timestamp': latest_entry['created_at']}]
  return None


# Paso 2: Simular la transmisión de datos a un servidor
def transmit_data(data):
  return json.dumps(data)

# Paso 3: Procesar los datos recibidos y detectar anomalías
def process_data(data_json):
  data = json.loads(data_json)
  anomalies = []
  for entry in data:
    print(entry['temperature'])
    if entry['temperature'] < 0 or entry['temperature'] > 35: anomalies.append(entry)
  return anomalies

# Paso 4: Tomar acciones basadas en las anomalías detectadas
def take_action(anomalies):
  for anomaly in anomalies:
    print(f"{Fore.RED} Alerta: Temperatura anómala detectada en el sensor {anomaly['sensor_id']} con {anomaly['temperature']} °C")

# Ejecutar la práctica completa
while True:
  sensor_data = simulate_temperature_data()
  print(f"{Fore.WHITE} Datos de sensores:", sensor_data)
  transmitted_data = transmit_data(sensor_data)
  print(f"{Fore.WHITE} Datos transmitidos:", transmitted_data)
  anomalies = process_data(transmitted_data)
  print(f"{Fore.WHITE} Anomalías detectadas:", anomalies)
  take_action(anomalies)
  time.sleep(10) # Esperar 1 segundo
# Out:
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 28.11, 'timestamp': '2024-06-20T04:27:00Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 28.11, "timestamp": "2024-06-20T04:27:00Z"}]
# 28.11
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 28.11, 'timestamp': '2024-06-20T04:27:00Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 28.11, "timestamp": "2024-06-20T04:27:00Z"}]
# 28.11
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -4.99, 'timestamp': '2024-06-20T04:27:21Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -4.99, "timestamp": "2024-06-20T04:27:21Z"}]
# -4.99
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -4.99, 'timestamp': '2024-06-20T04:27:21Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -4.99 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -4.99, 'timestamp': '2024-06-20T04:27:21Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -4.99, "timestamp": "2024-06-20T04:27:21Z"}]
# -4.99
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -4.99, 'timestamp': '2024-06-20T04:27:21Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -4.99 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 18.76, 'timestamp': '2024-06-20T04:27:41Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 18.76, "timestamp": "2024-06-20T04:27:41Z"}]
# 18.76
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 18.76, 'timestamp': '2024-06-20T04:27:41Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 18.76, "timestamp": "2024-06-20T04:27:41Z"}]
# 18.76
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -0.49, 'timestamp': '2024-06-20T04:28:01Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -0.49, "timestamp": "2024-06-20T04:28:01Z"}]
# -0.49
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -0.49, 'timestamp': '2024-06-20T04:28:01Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -0.49 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -0.49, 'timestamp': '2024-06-20T04:28:01Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -0.49, "timestamp": "2024-06-20T04:28:01Z"}]
# -0.49
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -0.49, 'timestamp': '2024-06-20T04:28:01Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -0.49 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 21.29, 'timestamp': '2024-06-20T04:28:21Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 21.29, "timestamp": "2024-06-20T04:28:21Z"}]
# 21.29
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 21.29, 'timestamp': '2024-06-20T04:28:21Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 21.29, "timestamp": "2024-06-20T04:28:21Z"}]
# 21.29
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -2.7, 'timestamp': '2024-06-20T04:28:42Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -2.7, "timestamp": "2024-06-20T04:28:42Z"}]
# -2.7
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -2.7, 'timestamp': '2024-06-20T04:28:42Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -2.7 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -2.7, 'timestamp': '2024-06-20T04:28:42Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -2.7, "timestamp": "2024-06-20T04:28:42Z"}]
# -2.7
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -2.7, 'timestamp': '2024-06-20T04:28:42Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -2.7 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -0.04, 'timestamp': '2024-06-20T04:29:02Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -0.04, "timestamp": "2024-06-20T04:29:02Z"}]
# -0.04
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -0.04, 'timestamp': '2024-06-20T04:29:02Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -0.04 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': -0.04, 'timestamp': '2024-06-20T04:29:02Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": -0.04, "timestamp": "2024-06-20T04:29:02Z"}]
# -0.04
#  Anomalías detectadas: [{'sensor_id': '2574321', 'temperature': -0.04, 'timestamp': '2024-06-20T04:29:02Z'}]
#  Alerta: Temperatura anómala detectada en el sensor 2574321 con -0.04 °C
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 15.65, 'timestamp': '2024-06-20T04:29:22Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 15.65, "timestamp": "2024-06-20T04:29:22Z"}]
# 15.65
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 15.65, 'timestamp': '2024-06-20T04:29:22Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 15.65, "timestamp": "2024-06-20T04:29:22Z"}]
# 15.65
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 15.65, 'timestamp': '2024-06-20T04:29:22Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 15.65, "timestamp": "2024-06-20T04:29:22Z"}]
# 15.65
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 15.65, 'timestamp': '2024-06-20T04:29:22Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 15.65, "timestamp": "2024-06-20T04:29:22Z"}]
# 15.65
#  Anomalías detectadas: []
#  Datos de sensores: [{'sensor_id': '2574321', 'temperature': 15.65, 'timestamp': '2024-06-20T04:29:22Z'}]
#  Datos transmitidos: [{"sensor_id": "2574321", "temperature": 15.65, "timestamp": "2024-06-20T04:29:22Z"}]
# 15.65
#  Anomalías detectadas: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-67944066e8c1> in <cell line: 44>()
#      50   print(f"{Fore.WHITE} Anomalías detectadas:", anomalies)
#      51   take_action(anomalies)
# ---> 52   time.sleep(10) # Esperar 1 segundo
#
# KeyboardInterrupt:
